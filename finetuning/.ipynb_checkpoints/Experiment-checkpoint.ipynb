# %%
import boto3

# %%
s3=boto3.client("s3")

# %%
response = s3.list_objects_v2(Bucket="llm-finetune-dataset-manjunath", Prefix="datasets/")

# %%
for obj in response.get("Contents", []):
    print(obj)
# Out:
# {'Key': 'datasets/', 'LastModified': datetime.datetime(2025, 11, 9, 9, 41, 22, tzinfo=tzlocal()), 'ETag': '"d41d8cd98f00b204e9800998ecf8427e"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 0, 'StorageClass': 'STANDARD'}
# {'Key': 'datasets/pharma_instruction_data.csv', 'LastModified': datetime.datetime(2025, 11, 9, 10, 39, 57, tzinfo=tzlocal()), 'ETag': '"7a3bbfb7acae4d8dc88dc1a08501d745"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 2469, 'StorageClass': 'STANDARD'}

# %%
for obj in response.get("Contents", []):
    print(obj["Key"])
# Out:
# datasets/
# datasets/pharma_instruction_data.csv

# %%
dataset_path = "s3://llm-finetune-dataset-manjunath/datasets/pharma_instruction_data.csv/"

# %%
dataset_path
# Out:
# 's3://llm-finetune-dataset-manjunath/datasets/pharma_instruction_data.csv/'

# %%
from datasets import load_dataset
import fsspec, s3fs, sentencepiece, datasets

# %%
dataset = load_dataset("csv",data_files={"train":dataset_path})

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 5
#     })
# })

# %%
print(dataset["train"])
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 5
# })

# %%
print(dataset["train"][0])
# Out:
# {'instruction': 'Explain the mechanism of action of Metformin.', 'input': None, 'output': 'Metformin activates AMP-activated protein kinase (AMPK), which increases glucose uptake and fatty-acid oxidation while inhibiting hepatic gluconeogenesis, thereby lowering blood glucose.'}
